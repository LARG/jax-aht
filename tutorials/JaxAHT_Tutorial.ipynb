# %% [markdown]
# # Welcome to JaxAHT!
#
# *Please open this notebook in Colab.
#
# In this tutorial, we will focus on introducing the core workflows for using the library.
# We will:
# - Demonstrate how to train teammates and ego agents, separately and as part of a single, unified workflow.
# - Introduce the set of evaluation teammates and the evaluation framework
# - Visualize learned policies
#
# The project uses [Hydra](https://hydra.cc/) to manage algorithm and environment configurations, and [WandB](https://wandb.ai/) for logging.
#
# Although the tutorial does not explicitly describe how to run the open-ended learning algorithms, these algorithm types may be run similarly to the MARL, teammate generation, and ego agent training algorithms.
#
# Please see the project README for a full description of the project's design philosophy.
# Our benchmark uses a multi-agent PPO implementation provided by [JaxMARL](https://github.com/FLAIROx/JaxMARL/tree/main).

# %% [markdown]
# # Install dependencies 📚
#
#  ⚠️ Before beginning the tutorial, ensure you select a GPU or TPU from `Runtime > Change runtime type` ⚠️
#
#  And Make sure that you select a runtime with python 3.11
#
#  If none existant, you can use the following script to install py311

# %%
# !wget https://github.com/korakot/kora/releases/download/v0.11/py311.sh
# !bash ./py311.sh -b -f -p /usr/local
# !python -m ipykernel install --name "py311" --user

# %%
# %%shell
# # clone repo and install packages
# git clone https://github.com/LARG/jax-aht.git
#
# cd jax-aht
# pip install --upgrade pip
# pip install -e .
# # pip install numpy==1.25.* --upgrade # forcefully downgrade numpy; necessary for colab only

# %% [markdown]
# Use the following script to force (downgrade the versions)
#
# You will be prompt to restart the session after numpy 1.25.2 is installed

# %%
# %pip uninstall -y numpy
# %pip install numpy==1.25.2 scipy==1.12.0
import numpy
print(numpy.__version__)

# %%
# Now check to make sure that we get 1.15.2
import numpy
print(numpy.__version__) # 1.25.2
# Out:
# 1.25.2

# %%
# change current working directory to jax-aht/ for the rest of this notebook
import os

path = os.getcwd()
if not path.endswith("jax-aht"):
    # if we are using the notebook from the repository directly
    if os.getcwd().endswith("jax-aht/tutorials"):
        os.chdir("..")
    # if we cloned the repository
    else:
        os.chdir("jax-aht")

print(os.getcwd()) # <path>/jax-aht

# verify that the jax installation can find the GPU/TPU
import jax
jax.devices()
# Out:
# /scratch/cluster/jyliu/Documents/jax-aht
# [CudaDevice(id=0), CudaDevice(id=1), CudaDevice(id=2), CudaDevice(id=3)]

# %% [markdown]
# ## Part 1.1 Training Teammates
#
#
# In Jax-AHT, teammates may be trained using either MARL algorithms, or teammate generation algorithms. Each algorithm type has its own entry point, located at `marl/run.py` and `teammate_generation/run.py` respectively.
# For this tutorial, we will train teammates on Level-Based Foraging (LBF) using IPPO.
#
#
# **Viewing Metrics:**    We strongly recommend using WandB's UI to view the logged metrics. You will need a WandB account, and to set the logger to online mode. For the purposes of this tutorial, you can see a preview of the loggged metrics in the console. Note that the maximum return on LBF is 0.5.

# %%
# %%shell
# # train teammates on LBF using a MARL algorithm (IPPO w/parameter sharing)
# PYTHONPATH=$(pwd) python marl/run.py task=lbf algorithm=ippo/lbf logger.mode=offline
# # train using BRDiv instead. Note that we use the teammate_generation/ entry point instead of the marl/ entry point.
# # PYTHONPATH=$(pwd) python teammate_generation/run.py task=lbf algorithm=brdiv/lbf logger.mode=offline
# Out:
# task:
#   ENV_NAME: lbf
#   ROLLOUT_LENGTH: 128
#   ENV_KWARGS: {}
#   TASK_NAME: lbf
# algorithm:
#   ALG: ippo
#   TOTAL_TIMESTEPS: 500000.0
#   ACTOR_TYPE: mlp
#   NUM_CHECKPOINTS: 5
#   GAMMA: 0.99
#   GAE_LAMBDA: 0.95
#   VF_COEF: 0.5
#   MAX_GRAD_NORM: 1.0
#   ANNEAL_LR: true
#   SEED: 12345
#   LR: 0.0001
#   NUM_ENVS: 8
#   UPDATE_EPOCHS: 15
#   NUM_MINIBATCHES: 4
#   CLIP_EPS: 0.03
#   ENT_COEF: 0.01
#   NUM_SEEDS: 3
#   TRAIN_SEED: 20374
#   ENV_NAME: lbf
#   ENV_KWARGS: {}
#   ROLLOUT_LENGTH: 128
# ENV_NAME: lbf
# ENV_KWARGS: {}
# ROLLOUT_LENGTH: 128
# TASK_NAME: lbf
# label: default_label
# name: lbf/ippo/default_label
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#   - ippo
#   - lbf
#   - seed=20374
#   - default_label
#   mode: offline
#   verbose: false
#   log_train_out: true
#   log_eval_out: true
# local_logger:
#   save_train_out: true
#   save_eval_out: true
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: Tracking run with wandb version 0.19.9
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# wandb: Adding directory to artifact (/scratch/cluster/jyliu/Documents/jax-aht/results/lbf/ippo/default_label/2025-09-11_21-56-10/saved_train_run)... Done. 0.2s
# wandb:
# wandb:
# wandb: Run history:
# wandb: Train/returned_episode_returns ▁▁▁▁▁▂▂▁▃▃▄���▅▄▅▅▆▆▇▇▇▇▇█████████████████
# wandb:                     train_step ▁▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██
# wandb:
# wandb: Run summary:
# wandb: Train/returned_episode_returns 0.49405
# wandb:                     train_step 487
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /scratch/cluster/jyliu/Documents/jax-aht/results/lbf/ippo/default_label/2025-09-11_21-56-10/wandb/offline-run-20250911_215610-2sa1giui
# wandb: Find logs at: ./wandb/offline-run-20250911_215610-2sa1giui/logs

# %% [markdown]
# ## Part 1.2: Training an Ego Agent Against Pretrained Teammate
#
# Using the IPPO teammates trained in the last section, here, we will train a PPO ego agent to collaborate with those teammates, using the ego agent training entry point at `ego_agent_training/run.py`.
#
# Please take a moment to look over the entry point code, to understand the overall pipeline.

# %%
! cat ego_agent_training/run.py
# Out:
# /scratch/cluster/jyliu/conda_envs/AHT/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# '''Main entry point for running ego agent training algorithms against a fixed partner population.'''
# import hydra
# from omegaconf import OmegaConf
#
# from common.plot_utils import get_metric_names
# from common.wandb_visualizations import Logger
# from evaluation.heldout_eval import run_heldout_evaluation, log_heldout_metrics
# from ppo_ego import run_ego_training
# from ego_agent_training.ppo_br import run_br_training
#
#
# @hydra.main(version_base=None, config_path="configs", config_name="base_config_ego")
# def run_training(cfg):
#     '''Runs the ego agent training against a fixed partner population.'''
#     print(OmegaConf.to_yaml(cfg, resolve=True))
#     wandb_logger = Logger(cfg)
#
#     if cfg["algorithm"]["ALG"] == "ppo_ego":
#         ego_params, ego_policy, init_ego_params = run_ego_training(cfg, wandb_logger)
#     elif cfg["algorithm"]["ALG"] == "ppo_br":
#         ego_params, ego_policy, init_ego_params = run_br_training(cfg, wandb_logger)
#
#     if cfg["run_heldout_eval"]:
#         metric_names = get_metric_names(cfg["ENV_NAME"])
#         eval_metrics, ego_names, heldout_names = run_heldout_evaluation(cfg, ego_policy, ego_params, init_ego_params, ego_as_2d=False)
#         log_heldout_metrics(cfg, wandb_logger, eval_metrics, ego_names, heldout_names, metric_names, ego_as_2d=False)
#
#     # Cleanup
#     wandb_logger.close()
#
#
# if __name__ == '__main__':
#     run_training()

# %% [markdown]
# ### 1.2.1: Setting the Partner Config
#
# The first step to training an ego agent is to specify what teammates the ego agent should be trained with.
# The ego agent training code looks for a partner config within the algorithm block of the master config file, located at `rotate/ego_agent_training/configs/base_config_ego.yaml`.

# %%
! cat ego_agent_training/configs/base_config_ego.yaml
# Out:
# defaults:
#   - task: overcooked-v1/cramped_room # task configs
#   - algorithm@algorithm: ppo_ego/${task} # task-specific algorithm configs
#   - hydra: hydra_simple
#   - ../../evaluation/configs/global_heldout_settings
#   - _self_         # Ensures that values in this file override imported ones if needed
#
# ENV_NAME: ${task.ENV_NAME}
# ENV_KWARGS: ${task.ENV_KWARGS}
# ROLLOUT_LENGTH: ${task.ROLLOUT_LENGTH}
# TASK_NAME: ${task.TASK_NAME}
#
# run_heldout_eval: true
#
# # partner configs are specified in each algorithm _base_ config file
# # note that ppo_ego and ppo_br support different types of partner configs
# algorithm:
#   TRAIN_SEED: 12345
#   NUM_EGO_TRAIN_SEEDS: 3
#   NUM_EVAL_EPISODES: 20
#   ENV_NAME: ${ENV_NAME}
#   ENV_KWARGS: ${ENV_KWARGS}
#   ROLLOUT_LENGTH: ${ROLLOUT_LENGTH}
#
# label: "default_label"
# name: ${TASK_NAME}/${algorithm.ALG}_${algorithm.EGO_ACTOR_TYPE}/${label}
#
# # WandB Params
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#     - ${algorithm.ALG}
#     - ${TASK_NAME}
#     - ${label}
#   mode: offline # options: online, offline, disabled
#   verbose: false
#   log_train_out: true # whether to log the out dictionary
#   log_eval_out: true # whether to log the eval metrics
#
# # Local logger
# local_logger:
#   save_train_out: true
#   save_eval_out: true

# %% [markdown]
# For the ppo_ego algorithm, a default partner config is specified within the algorithm-specific config directory, at `rotate/ego_agent_training/configs/algorithm/ppo_ego/_base_.yaml`. This default partner config is automatically imported and merged into the master config. The path (and other partner config values) should be set by the user, either directly within the config or via the command line. We will take the latter approach in this tutorial.

# %%
! cat ego_agent_training/configs/algorithm/ppo_ego/_base_.yaml
# Out:
# # @package algorithm
# # ^ tells hydra to place these value directly under algorithm key
# ALG: ppo_ego
# EGO_ACTOR_TYPE: s5
# NUM_EGO_TRAIN_SEEDS: 1
# TOTAL_TIMESTEPS: 1e7
# NUM_CHECKPOINTS: 5
# NUM_ENVS: 8
# LR: 1.e-4
# UPDATE_EPOCHS: 15
# NUM_MINIBATCHES: 4
# GAMMA: 0.99
# GAE_LAMBDA: 0.95
# CLIP_EPS: 0.05
# ENT_COEF: 0.01
# VF_COEF: 0.5
# MAX_GRAD_NORM: 1.0
# ANNEAL_LR: true
# partner_agent: # partner config for ppo_ego
#   name: ippo
#   path: null # Please set the path to a partner agent checkpoint. You will also need to set the actor_type, ckpt_key, and specify the partner idxs to load.
#   actor_type: mlp
#   ckpt_key: final_params
#   idx_list: [0]

# %%
# First, let's find the teammate checkpoint directory
import glob

checkpoint_base_dir = 'results/lbf/ippo/default_label/'
checkpoint_dir = sorted(glob.glob(os.path.join(checkpoint_base_dir, '*')))[-1]
checkpoint_dir = os.path.join(checkpoint_dir, "saved_train_run")
assert os.path.exists(checkpoint_dir), "Error: checkpoint directory not found."
print(f"Found checkpoint directory: {checkpoint_dir}")
# Out:
# Found checkpoint directory: results/lbf/ippo/default_label/2025-09-11_21-56-10/saved_train_run

# %% [markdown]
# ### 1.2.2: Train the ego agent!
#
# Now let's train the ego agent, directly specifying the partner path as a command line argument. We reduce the training time to 1 million steps, so that the ego agent trains in a couple minutes. We also turn off the evaluation against the heldout set, which is explained in the next section.

# %%
# Now let's train the ego agent, directly specifying the partner path from the command line
# total training timesteps is reduced to 1 million steps for this tutorial.
! PYTHONPATH=$(pwd) python ego_agent_training/run.py task=lbf algorithm=ppo_ego/lbf algorithm.partner_agent.path={checkpoint_dir} algorithm.TOTAL_TIMESTEPS=1e6 run_heldout_eval=false logger.mode=offline
# Out:
# task:
#   ENV_NAME: lbf
#   ROLLOUT_LENGTH: 128
#   ENV_KWARGS: {}
#   TASK_NAME: lbf
# algorithm:
#   ALG: ppo_ego
#   EGO_ACTOR_TYPE: s5
#   NUM_EGO_TRAIN_SEEDS: 3
#   TOTAL_TIMESTEPS: 1000000.0
#   NUM_CHECKPOINTS: 5
#   NUM_ENVS: 8
#   LR: 5.0e-05
#   UPDATE_EPOCHS: 10
#   NUM_MINIBATCHES: 4
#   GAMMA: 0.99
#   GAE_LAMBDA: 0.95
#   CLIP_EPS: 0.1
#   ENT_COEF: 0.0001
#   VF_COEF: 0.5
#   MAX_GRAD_NORM: 1.0
#   ANNEAL_LR: false
#   partner_agent:
#     name: ippo
#     path: results/lbf/ippo/default_label/2025-09-11_21-56-10/saved_train_run
#     actor_type: mlp
#     ckpt_key: final_params
#     idx_list:
#     - 0
#   S5_D_MODEL: 128
#   S5_SSM_SIZE: 128
#   S5_ACTOR_CRITIC_HIDDEN_DIM: 1024
#   FC_N_LAYERS: 3
#   TRAIN_SEED: 12345
#   NUM_EVAL_EPISODES: 20
#   ENV_NAME: lbf
#   ENV_KWARGS: {}
#   ROLLOUT_LENGTH: 128
# global_heldout_settings:
#   EVAL_SEED: 34957
#   MAX_EPISODE_STEPS: 128
#   NUM_EVAL_EPISODES: 64
#   AGGREGATE_STAT: mean
#   NORMALIZE_RETURNS: true
# heldout_set:
#   lbf:
#     ippo_mlp:
#       path: eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 100.0
#         returned_episode_returns:
#         - - 0.0
#           - 0.5
#     ippo_mlp_s2c0:
#       path: eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run
#       actor_type: mlp
#       idx_list:
#       - - 2
#         - 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 69.27
#         returned_episode_returns:
#         - - 0.0
#           - 0.35
#     brdiv-conf1:
#       path: eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 5
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 61.98
#         - - 0.0
#           - 83.33
#         - - 0.0
#           - 78.65
#         returned_episode_returns:
#         - - 0.0
#           - 0.31
#         - - 0.0
#           - 0.42
#         - - 0.0
#           - 0.39
#     brdiv-conf2:
#       path: eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 90.62
#         - - 0.0
#           - 52.08
#         returned_episode_returns:
#         - - 0.0
#           - 0.45
#         - - 0.0
#           - 0.26
#     seq_agent_lexi:
#       actor_type: seq_agent
#       ordering_strategy: lexicographic
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_rlexi:
#       actor_type: seq_agent
#       ordering_strategy: reverse_lexicographic
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_col:
#       actor_type: seq_agent
#       ordering_strategy: column_major
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_rcol:
#       actor_type: seq_agent
#       ordering_strategy: reverse_column_major
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_nearest:
#       actor_type: seq_agent
#       ordering_strategy: nearest_agent
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_farthest:
#       actor_type: seq_agent
#       ordering_strategy: farthest_agent
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#   overcooked-v1/cramped_room:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/cramped_room/ippo/2025-04-21_22-53-04/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 196.25
#         - - 0.0
#           - 180.94
#         - - 0.0
#           - 211.88
#         returned_episode_returns:
#         - - 0.0
#           - 209.55
#         - - 0.0
#           - 193.39
#         - - 0.0
#           - 226.68
#     brdiv-conf:
#       path: eval_teammates/overcooked-v1/cramped_room/brdiv/2025-04-23-12-55-47/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 204.06
#         - - 0.0
#           - 240.94
#         returned_episode_returns:
#         - - 0.0
#           - 217.77
#         - - 0.0
#           - 257.61
#     independent_agent_0.4:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.4
#       p_plate_on_counter: 0.4
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 158.75
#         returned_episode_returns:
#         - 0.0
#         - 169.27
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 132.5
#         returned_episode_returns:
#         - 0.0
#         - 133.64
#     onion_agent_0.1:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.1
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 83.13
#         returned_episode_returns:
#         - 0.0
#         - 89.34
#     plate_agent_0.1:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.1
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 137.5
#         returned_episode_returns:
#         - 0.0
#         - 146.45
#   overcooked-v1/asymm_advantages:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/asymm_advantages/ippo/2025-04-21_22-53-56/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 91.56
#         - - 0.0
#           - 117.5
#         - - 0.0
#           - 153.44
#         returned_episode_returns:
#         - - 0.0
#           - 91.56
#         - - 0.0
#           - 117.5
#         - - 0.0
#           - 153.44
#     brdiv-conf:
#       path: eval_teammates/overcooked-v1/asymm_advantages/brdiv/2025-04-23/13-16-34/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 157.81
#         - - 0.0
#           - 148.44
#         - - 0.0
#           - 160.0
#         returned_episode_returns:
#         - - 0.0
#           - 157.81
#         - - 0.0
#           - 148.44
#         - - 0.0
#           - 160.0
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 257.5
#         returned_episode_returns:
#         - 0.0
#         - 257.5
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 199.69
#         returned_episode_returns:
#         - 0.0
#         - 199.69
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 191.25
#         returned_episode_returns:
#         - 0.0
#         - 191.25
#   overcooked-v1/counter_circuit:
#     ippo_mlp_cc:
#       path: eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-21_22-55-42/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 196.88
#         - - 0.0
#           - 198.12
#         - - 0.0
#           - 189.06
#         returned_episode_returns:
#         - - 0.0
#           - 209.12
#         - - 0.0
#           - 210.51
#         - - 0.0
#           - 207.01
#     ippo_mlp_pass:
#       path: eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-23_15-28-23/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 59.38
#         - - 0.0
#           - 46.25
#         - - 0.0
#           - 142.5
#         returned_episode_returns:
#         - - 0.0
#           - 62.86
#         - - 0.0
#           - 47.63
#         - - 0.0
#           - 150.6
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 65.0
#         returned_episode_returns:
#         - 0.0
#         - 65.5
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 62.5
#         returned_episode_returns:
#         - 0.0
#         - 65.93
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 56.25
#         returned_episode_returns:
#         - 0.0
#         - 58.79
#     onion_agent_0.9:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.9
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 46.25
#         returned_episode_returns:
#         - 0.0
#         - 48.62
#     plate_agent_0.9:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.9
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 55.31
#         returned_episode_returns:
#         - 0.0
#         - 57.91
#   overcooked-v1/coord_ring:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/coord_ring/ippo/2025-04-21_22-58-26/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 1
#       - 2
#       - 3
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 218.44
#         - - 0.0
#           - 246.56
#         - - 0.0
#           - 246.56
#         returned_episode_returns:
#         - - 0.0
#           - 232.62
#         - - 0.0
#           - 262.83
#         - - 0.0
#           - 262.83
#     brdiv-conf1:
#       path: eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_15-00-27/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 161.25
#         - - 0.0
#           - 183.44
#         returned_episode_returns:
#         - - 0.0
#           - 171.35
#         - - 0.0
#           - 194.6
#     brdiv-conf2:
#       path: eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 142.81
#         returned_episode_returns:
#         - - 0.0
#           - 150.98
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 136.25
#         returned_episode_returns:
#         - 0.0
#         - 137.08
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 38.13
#         returned_episode_returns:
#         - 0.0
#         - 40.25
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 67.5
#         returned_episode_returns:
#         - 0.0
#         - 70.33
#   overcooked-v1/forced_coord:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 220.0
#         - - 0.0
#           - 214.38
#         - - 0.0
#           - 225.62
#         returned_episode_returns:
#         - - 0.0
#           - 233.83
#         - - 0.0
#           - 227.73
#         - - 0.0
#           - 239.82
#     brdiv-conf1:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_19-44-30/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 131.56
#         - - 0.0
#           - 184.69
#         returned_episode_returns:
#         - - 0.0
#           - 139.33
#         - - 0.0
#           - 195.88
#     brdiv-conf2:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_20-25-28/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 143.75
#         returned_episode_returns:
#         - - 0.0
#           - 152.5
#     brdiv-conf3:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_21-06-05/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 69.06
#         - - 0.0
#           - 174.69
#         returned_episode_returns:
#         - - 0.0
#           - 72.45
#         - - 0.0
#           - 185.49
#     independent_agent_0.6:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.6
#       p_plate_on_counter: 0.6
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 61.88
#         returned_episode_returns:
#         - 0.0
#         - 65.22
# ENV_NAME: lbf
# ENV_KWARGS: {}
# ROLLOUT_LENGTH: 128
# TASK_NAME: lbf
# run_heldout_eval: false
# label: default_label
# name: lbf/ppo_ego_s5/default_label
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#   - ppo_ego
#   - lbf
#   - default_label
#   mode: offline
#   verbose: false
#   log_train_out: true
#   log_eval_out: true
# local_logger:
#   save_train_out: true
#   save_eval_out: true
#
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: Tracking run with wandb version 0.19.9
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# /scratch/cluster/jyliu/conda_envs/AHT/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/type_handlers.py:1167: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(
# [2025-09-11 21:57:53,107][common.agent_loader_from_config][INFO] - Loaded ippo checkpoint where leaf 0 has shape (3, 64).  Selecting indices [0] for evaluation.
# [2025-09-11 21:58:12,323][ppo_ego][INFO] - Starting ego agent training...
# /scratch/cluster/jyliu/conda_envs/AHT/lib/python3.11/site-packages/jax/_src/lax/lax.py:5125: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# [2025-09-11 22:02:09,769][ppo_ego][INFO] - Training completed in 237.44 seconds
# wandb: Adding directory to artifact (/scratch/cluster/jyliu/Documents/jax-aht/results/lbf/ppo_ego_s5/default_label/2025-09-11_21-57-50/ego_train_run)... Done. 8.5s
# wandb:
# wandb:
# wandb: Run history:
# wandb:                     Eval/EgoReturn ▁▁▁▁▁▁▁▁▁███████████████████████████████
# wandb:                 Train/EgoActorLoss ▁▂▄▅█▄▃▅██▄█▇▇▇▆▇▄▂▆▂▅▆▅▄▇▆▂▅▄▇▄▂▆▄▆▄▄▄▂
# wandb:               Train/EgoEntropyLoss ███▇▅▂▂▂▂▂▂▂▂▂▂▁▁▂▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  Train/EgoGradNorm ▁▂▃▅▇█▇█▅▆▆▅█▄▄▆▆▄▅▃▅▅▆▇▄▅▄▇▅▄▄▅▅▅▅▃▃▃▄▃
# wandb:                 Train/EgoValueLoss ▆▅▆█▅▅▄▅▃▃▅▃▂▂▁▁▁▂▁▁▁▃▁▁▃▁▂▂▂▂▂▁▂▃▁▁▁▁▁▁
# wandb: Train/Ego_returned_episode_returns ▁▃▇▇▇███████████████████████████████████
# wandb:                         train_step ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇█████
# wandb:
# wandb: Run summary:
# wandb:                     Eval/EgoReturn 0.49444
# wandb:                 Train/EgoActorLoss -0.01444
# wandb:               Train/EgoEntropyLoss 0.31275
# wandb:                  Train/EgoGradNorm 0.11902
# wandb:                 Train/EgoValueLoss 0.00054
# wandb: Train/Ego_returned_episode_returns 0.49794
# wandb:                         train_step 975
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /scratch/cluster/jyliu/Documents/jax-aht/results/lbf/ppo_ego_s5/default_label/2025-09-11_21-57-50/wandb/offline-run-20250911_215750-qefq3ejw
# wandb: Find logs at: ./wandb/offline-run-20250911_215750-qefq3ejw/logs

# %% [markdown]
# # 2. Evaluation
#
# In AHT research, ego agents are often evaluated based on the returns achieved during collaboration with a *heldout set* of evaluation agents---i.e., agents that should not have been seen during training.
# The JaxAHT benchmark provides a heldout evaluation set for LBF, and the 5 classic Overcooked tasks.
# The rliable library is used to compute bootstrapped metrics across the heldout set, by treating each heldout agent as a task.
# In this section of the tutorial, we will introduce the heldout agent config, demonstrate how to download the agents, and visualize them.
#
# *Note that the ego agent training entry point evaluate the ego agent against the heldout set by default. We turned this off in the last section, but you simply need to set the `run_heldout_eval` argument to true in order to enable evaluation.

# %% [markdown]
#  ## 2.1 Download the Heldout Set
#
#
#  The heldout evaluation set consists of both agents trained via RL, and manually programmed heuristic agents. The heuristic agents are located under the `agents/lbf/` and `agents/overcooked/` directories, while the following code will download the RL agent checkpoints to an `eval_teammates/` directory.

# %%
# first, let's download the RL agents in the heldout set
! python download_eval_data.py
# Out:
# Starting download & extraction: https://drive.google.com/file/d/1pS0wvJDzOZa954RADF_j9ETR74THzh8I/view?usp=sharing -> results/
# Downloading...
# From: https://drive.google.com/uc?id=1pS0wvJDzOZa954RADF_j9ETR74THzh8I
# To: /scratch/cluster/jyliu/Documents/jax-aht/results/downloaded_gdrive_file.zip
# 100%|██████████████████████████████████████| 5.94k/5.94k [00:00<00:00, 27.8MB/s]
# Downloaded results/downloaded_gdrive_file.zip (5942 bytes).
# Unzipping results/downloaded_gdrive_file.zip to temporary directory /tmp/tmppfgekeiq...
# Successfully unzipped results/downloaded_gdrive_file.zip to /tmp/tmppfgekeiq.
# Processing and moving files from '/tmp/tmppfgekeiq/best_heldout_returns' to 'results/'...
# Warning: Overwriting existing file 'results/lbf/best_heldout_returns.json'.
# Warning: Overwriting existing file 'results/overcooked-v1/coord_ring/best_heldout_returns.json'.
# Warning: Overwriting existing file 'results/overcooked-v1/cramped_room/best_heldout_returns.json'.
# Warning: Overwriting existing file 'results/overcooked-v1/counter_circuit/best_heldout_returns.json'.
# Warning: Overwriting existing file 'results/overcooked-v1/asymm_advantages/best_heldout_returns.json'.
# Warning: Overwriting existing file 'results/overcooked-v1/forced_coord/best_heldout_returns.json'.
# Successfully moved 6 file(s) to results/.
# Cleaning up temporary extraction directory: /tmp/tmppfgekeiq
# Download completed successfully for best_returns_teammates.
# Starting download & extraction: https://drive.google.com/file/d/1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7/view?usp=sharing -> eval_teammates/
# Downloading...
# From (original): https://drive.google.com/uc?id=1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7
# From (redirected): https://drive.google.com/uc?id=1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7&confirm=t&uuid=f555224a-7cf1-49b6-9db4-160273159661
# To: /scratch/cluster/jyliu/Documents/jax-aht/eval_teammates/downloaded_gdrive_file.zip
# 100%|████████████████████████████████████████| 852M/852M [00:15<00:00, 53.3MB/s]
# Downloaded eval_teammates/downloaded_gdrive_file.zip (851869349 bytes).
# Unzipping eval_teammates/downloaded_gdrive_file.zip to temporary directory /tmp/tmpamkn2t54...
# Successfully unzipped eval_teammates/downloaded_gdrive_file.zip to /tmp/tmpamkn2t54.
# Processing and moving files from '/tmp/tmpamkn2t54/eval_teammates' to 'eval_teammates/'...
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/run.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/_CHECKPOINT_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/_sharding'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/ed2773f8157161b46ea3f72e18ae40bc'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/919db8cedcac849456fbc590221e9b03'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/adeffbfcde9cb144f51db2d31c00d8dc'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/673c1c6bd5e0f9799e14df827ae9b715'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/54b479f73361c85239e83b6b186ba5fe'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/ocdbt.process_0/d/b8296f0b4e811d237d7638f24c19efbb'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run/d/1e9b023face1625982c1b56515452d05'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/run-5d4r29l5.wandb'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/logs/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/logs/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/logs/debug-core.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/requirements.txt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/wandb-summary.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/wandb-metadata.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/output.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Eval/LastXPMatrix_7325_e23f563f47138782e02f.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/BREntropy_table_7331_f2bfcc807be94aea89c1.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/BRValLoss_table_7329_a8692e65bbc472f56127.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/ConfEntropy_table_7330_5bbd82019a5b606bbab7.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/ConfPGLoss_table_7326_c980073876a092de0ffc.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/BRPGLoss_table_7327_e77bbb831add1de75ed1.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/latest-run/files/media/table/Losses/ConfValLoss_table_7328_f8a69654b4e331a73cb4.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/run-5d4r29l5.wandb'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/logs/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/logs/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/logs/debug-core.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/requirements.txt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/wandb-summary.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/wandb-metadata.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/output.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Eval/LastXPMatrix_7325_e23f563f47138782e02f.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/BREntropy_table_7331_f2bfcc807be94aea89c1.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/BRValLoss_table_7329_a8692e65bbc472f56127.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/ConfEntropy_table_7330_5bbd82019a5b606bbab7.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/ConfPGLoss_table_7326_c980073876a092de0ffc.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/BRPGLoss_table_7327_e77bbb831add1de75ed1.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/wandb/run-20250416_113208-5d4r29l5/files/media/table/Losses/ConfValLoss_table_7328_f8a69654b4e331a73cb4.table.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/.hydra/overrides.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/.hydra/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-16/11-32-07/.hydra/hydra.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/run.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/_CHECKPOINT_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/_sharding'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/ocdbt.process_0/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run/ocdbt.process_0/d/c960044e581c1aba25aebe7121599155'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_
json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/.hydra/overrides.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/.hydra/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/brdiv/2025-04-23/13-48-47/.hydra/hydra.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=1_checkpoint=1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/ippo.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=0_checkpoint=-1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=0_checkpoint=1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/ippo_train_metrics_Percent Eaten.pdf'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=2_checkpoint=1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=2_checkpoint=-1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/ippo_train_metrics_Returned Episode Returns.pdf'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/seed=1_checkpoint=-1.mp4'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/_CHECKPOINT_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/_sharding'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/cf568039aabfc251e71ce07937561e42'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/8fd2d46bbd4b355af3d5b12463ec91a6'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/be7ba0b2136aab09db95c1e14f1f455f'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/962004545f064b9a6ee87eaabcae62dc'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/2f27d2ba0c79daf2083c544d5de57a95'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/ocdbt.process_0/d/1e392a37225cf7d46815afc888a6a506'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run/d/49ab5608c0c3c3e9cf29ca92be5ef03c'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/run-a7x4mqaq.wandb'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/logs/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/logs/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/logs/debug-core.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/requirements.txt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/wandb-summary.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/wandb-metadata.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/output.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/media/plotly/train_metrics/Percent Eaten_0_343e5ef3f3bec5530722.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/run-20250421_234118-a7x4mqaq/files/media/plotly/train_metrics/Returned Episode Returns_0_28768f7697b6e2181eff.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/run-a7x4mqaq.wandb'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/logs/debug-internal.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/logs/debug.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/logs/debug-core.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/requirements.txt'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/wandb-summary.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/wandb-metadata.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/output.log'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/media/plotly/train_metrics/Percent Eaten_0_343e5ef3f3bec5530722.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/wandb/latest-run/files/media/plotly/train_metrics/Returned Episode Returns_0_28768f7697b6e2181eff.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/.hydra/overrides.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/.hydra/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/lbf/ippo/2025-04-21_23-41-17/.hydra/hydra.yaml'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/run.log'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/_CHECKPOINT_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/_sharding'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/d/0d1c217d423c2d8be5354119e77833db'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/d/4f1e2b185f58192522ad21f0f893ca43'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/d/16730383e80bf8eb7aaf1a2a3be310a7'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/d/bf7347ba3394085c17622e3b8f30cc67'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/ocdbt.process_0/d/e317edcc2522a785ead6bf70cecd79bf'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run/d/12e1bfe74fbbeee3644bf4193b9bd976'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/_CHECKPOINT_METADATA'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/_sharding'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/ocdbt.process_0/manifest.ocdbt'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/ocdbt.process_0/d/5fbb50d135bedb60fa162c9699941dbb'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/ocdbt.process_0/d/568bfc95f209930e953ca293a3c4946e'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/ocdbt.process_0/d/fd483e17b553fc12535b0b28cb26e34e'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/ego_train_run/ocdbt.process_0/d/7cca26890b7f7352b88b79b8e9e098fb'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36
.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/wandb/run-20250421_230017-uavvdnik/files/media/plotly/train_metrics/Base Return_0_8678b7a3a3d978f5d225.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/wandb/run-20250421_230017-uavvdnik/files/media/plotly/train_metrics/Returned Episode Returns_0_01d9e1ef05525a56e3d1.plotly.json'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/.hydra/overrides.yaml'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/.hydra/config.yaml'.
# Warning: Overwriting existing file 'eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/.hydra/hydra.yaml'.
# Successfully moved 1029 file(s) to eval_teammates/.
# Cleaning up temporary extraction directory: /tmp/tmpamkn2t54
# Download completed successfully for eval_teammates.

# %% [markdown]
# ## 2.2. Heldout Agent Config
#
# The evaluation teammate set is specified in the `global_heldout_settings.yaml` file, which is imported by other config files throughout the codebase as needed, to perform the heldout evaluation.
#
# Notice that the teammate config format looks similar to the format used to specify the ego agent training teammates! This is because all teammate configs are parsed by functions within the `common/agent_loader_from_config.py` file. Please see the README for more details about the teammate config.

# %%
! cat evaluation/configs/global_heldout_settings.yaml
# Out:
# # @package _global_
# # THIS SCRIPT CONTAINS THE PATHS FOR THE HELDOUT EVALUATION. MODIFY WITH CAUTION.
# global_heldout_settings:
#   EVAL_SEED: 34957
#   MAX_EPISODE_STEPS: ${task.ROLLOUT_LENGTH}
#   NUM_EVAL_EPISODES: 64
#   AGGREGATE_STAT: mean # choices: mean, iqm. both are computed with the bootstrapped CI using rliable.
#   NORMALIZE_RETURNS: true # if true, use performance bounds to normalize returns
#
# heldout_set:
#   lbf: # DONE - DO NOT MODIFY. In LBF, results are much better with test mode = false.
#     ippo_mlp:
#       path: "eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0] # load in seed 0 only
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 100.0]]
#         returned_episode_returns: [[0.0, 0.5]]
#     ippo_mlp_s2c0:
#       path: "eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run"
#       actor_type: mlp
#       idx_list: [[2, 0]] # load in seed 2 ckpt 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 69.27]]
#         returned_episode_returns: [[0.0, 0.35]]
#     brdiv-conf1:
#       path: "eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1, 2] # load in population members 0, 1, 2
#       ckpt_key: final_params_conf # key to load from checkpoint.
#       POP_SIZE: 5 # for brdiv, we need to specify population size that the method was trained with
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 61.98], [0.0, 83.33], [0.0, 78.65]]
#         returned_episode_returns: [[0.0, 0.31], [0.0, 0.42], [0.0, 0.39]]
#     brdiv-conf2:
#       path: "eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 90.62], [0.0, 52.08]]
#         returned_episode_returns: [[0.0, 0.45], [0.0, 0.26]]
#     seq_agent_lexi:
#       actor_type: seq_agent
#       ordering_strategy: lexicographic
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_rlexi:
#       actor_type: seq_agent
#       ordering_strategy: reverse_lexicographic
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_col:
#       actor_type: seq_agent
#       ordering_strategy: column_major
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_rcol:
#       actor_type: seq_agent
#       ordering_strategy: reverse_column_major
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_nearest:
#       actor_type: seq_agent
#       ordering_strategy: nearest_agent
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_farthest:
#       actor_type: seq_agent
#       ordering_strategy: farthest_agent
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#   overcooked-v1/cramped_room: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/cramped_room/ippo/2025-04-21_22-53-04/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 196.25], [0.0, 180.94], [0.0, 211.88]]
#         returned_episode_returns: [[0.0, 209.55], [0.0, 193.39], [0.0, 226.68]]
#     brdiv-conf:
#       path: "eval_teammates/overcooked-v1/cramped_room/brdiv/2025-04-23-12-55-47/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1] # load in population members 1, 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return: [[0.0, 204.06], [0.0, 240.94]]
#         returned_episode_returns: [[0.0, 217.77], [0.0, 257.61]]
#     independent_agent_0.4:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.4
#       p_plate_on_counter: 0.4
#       performance_bounds:
#         base_return: [0.0, 158.75]
#         returned_episode_returns: [0.0, 169.27]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 132.5]
#         returned_episode_returns: [0.0, 133.64]
#     onion_agent_0.1:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.1
#       performance_bounds:
#         base_return: [0.0, 83.13]
#         returned_episode_returns: [0.0, 89.34]
#     plate_agent_0.1:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.1
#       performance_bounds:
#         base_return: [0.0, 137.5]
#         returned_episode_returns: [0.0, 146.45]
#   overcooked-v1/asymm_advantages: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/asymm_advantages/ippo/2025-04-21_22-53-56/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 91.56], [0.0, 117.50], [0.0, 153.44]]
#         returned_episode_returns: [[0.0, 91.56], [0.0, 117.50], [0.0, 153.44]]
#     brdiv-conf:
#       path: "eval_teammates/overcooked-v1/asymm_advantages/brdiv/2025-04-23/13-16-34/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return: [[0.0, 157.81], [0.0, 148.44], [0.0, 160.00]]
#         returned_episode_returns: [[0.0, 157.81], [0.0, 148.44], [0.0, 160.00]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 257.5]
#         returned_episode_returns: [0.0, 257.5]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 199.69]
#         returned_episode_returns: [0.0, 199.69]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 191.25]
#         returned_episode_returns: [0.0, 191.25]
#   overcooked-v1/counter_circuit: # DONE - DO NOT MODIFY
#     ippo_mlp_cc: # counterclockwise mmt
#       path: "eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-21_22-55-42/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 196.88], [0.0, 198.12], [0.0, 189.06]]
#         returned_episode_returns: [[0.0, 209.12], [0.0, 210.51], [0.0, 207.01]]
#     ippo_mlp_pass: # passes onions across counter
#       path: "eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-23_15-28-23/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 59.38], [0.0, 46.25], [0.0, 142.5]] # RE-EVALUATE
#         returned_episode_returns: [[0.0, 62.86], [0.0, 47.63], [0.0, 150.60]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 65.0]
#         returned_episode_returns: [0.0, 65.5]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 62.5]
#         returned_episode_returns: [0.0, 65.93]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 56.25]
#         returned_episode_returns: [0.0, 58.79]
#     onion_agent_0.9:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.9
#       performance_bounds:
#         base_return: [0.0, 46.25]
#         returned_episode_returns: [0.0, 48.62]
#     plate_agent_0.9:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.9
#       performance_bounds:
#         base_return: [0.0, 55.31]
#         returned_episode_returns: [0.0, 57.91]
#   overcooked-v1/coord_ring: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/coord_ring/ippo/2025-04-21_22-58-26/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [1, 2, 3]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 218.44], [0.0, 246.56], [0.0, 246.56]]
#         returned_episode_returns: [[0.0, 232.62], [0.0, 262.83], [0.0, 262.83]]
#     brdiv-conf1:
#       path: "eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_15-00-27/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [1, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 161.25], [0.0, 183.44]]
#         returned_episode_returns: [[0.0, 171.35], [0.0, 194.60]]
#     brdiv-conf2:
#       path: "eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 142.81]]
#         returned_episode_returns: [[0.0, 150.98]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 136.25]
#         returned_episode_returns: [0.0, 137.08]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 38.13]
#         returned_episode_returns: [0.0, 40.25]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 67.5]
#         returned_episode_returns: [0.0, 70.33]
#   overcooked-v1/forced_coord:  # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 220.00], [0.0, 214.38], [0.0, 225.62]]
#         returned_episode_returns: [[0.0, 233.83], [0.0, 227.73], [0.0, 239.82]]
#     brdiv-conf1:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_19-44-30/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 131.56], [0.0, 184.69]]
#         returned_episode_returns: [[0.0, 139.33], [0.0, 195.88]]
#     brdiv-conf2:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_20-25-28/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [1]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 143.75]]
#         returned_episode_returns: [[0.0, 152.50]]
#     brdiv-conf3:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_21-06-05/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 69.06], [0.0, 174.69]]
#         returned_episode_returns: [[0.0, 72.45], [0.0, 185.49]]
#     independent_agent_0.6:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.6
#       p_plate_on_counter: 0.6
#       performance_bounds:
#         base_return: [0.0, 61.88]
#         returned_episode_returns: [0.0, 65.22]

# %% [markdown]
# ## 2.3. Visualizing Agents
#
# We provide functions to visualize agents at `evaluation/vis_episodes.py`.
# Scripts to test the heuristic agents on LBF and Overcooked are also provided at `tests/test_lbf_agents.py` and `tests/test_overcooked_agents.py`.

# %%
import numpy as np
from typing import Dict, Tuple

from IPython.display import HTML
import jax

from envs import make_env
from agents.lbf import RandomAgent, SequentialFruitAgent

def run_episode(env, agent0, agent1, key) -> Tuple[Dict[str, float], int]:
    """Run a single episode with two heuristic agents.
    """
    # Reset environment
    key, subkey = jax.random.split(key)
    obs, state = env.reset(subkey)

    # Initialize episode tracking
    done = {agent: False for agent in env.agents}
    done['__all__'] = False
    total_rewards = {agent: 0.0 for agent in env.agents}
    num_steps = 0

    # Initialize agent states
    agent0_state = agent0.init_agent_state(0)
    agent1_state = agent1.init_agent_state(1)

    # Initialize state sequence
    state_seq = []
    while not done['__all__']:
        # Get actions from both agents with their states
        key, act0_rng, act1_rng = jax.random.split(key, 3)

        action0, agent0_state = agent0.get_action(obs["agent_0"], state, agent0_state, act0_rng)
        action1, agent1_state = agent1.get_action(obs["agent_1"], state, agent1_state, act1_rng)

        actions = {"agent_0": action0, "agent_1": action1}

        # Step environment
        key, subkey = jax.random.split(key)
        obs, state, rewards, done, info = env.step(subkey, state, actions)
        state_seq.append(state)

        # Update rewards
        for agent in env.agents:
            total_rewards[agent] += rewards[agent]

        num_steps += 1

    print(f"Episode finished. Total states collected: {len(state_seq)}")
    return total_rewards, num_steps, state_seq

def main(num_episodes,
         max_steps=100,
         visualize=False,
         save_video=False):
    print("Initializing environment...")
    env = make_env(env_name="lbf", env_kwargs={"time_limit": max_steps})

    print("Initializing agents...")
    # choices: lexicographic, reverse_lexicographic, column_major, reverse_column_major, nearest_agent, farthest_agent
    agent0 = SequentialFruitAgent(grid_size=7, num_fruits=3, ordering_strategy='lexicographic') # boxed
    agent1 = SequentialFruitAgent(grid_size=7, num_fruits=3, ordering_strategy='lexicographic') # not boxed

    print("Agent 0:", agent0.get_name())
    print("Agent 1:", agent1.get_name())

    # Run multiple episodes
    key = jax.random.PRNGKey(0)

    returns = []
    state_seq_all = []
    for episode in range(num_episodes):
        print(f"\nEpisode {episode + 1}/{num_episodes}")
        key, subkey = jax.random.split(key)
        total_rewards, num_steps, ep_states = run_episode(env, agent0, agent1, subkey)
        state_seq_all.extend(ep_states)  # Changed from += to extend for better list handling
        print(f"Total states in sequence after episode: {len(state_seq_all)}")

        # Calculate episode return
        episode_return = np.mean(list(total_rewards.values()))
        returns.append(episode_return)

        print(f"\nEpisode {episode + 1} finished:")
        print(f"Total steps: {num_steps}")
        print(f"Mean episode return: {episode_return:.2f}")
        print("Episode returns per agent:")
        for agent in env.agents:
            print(f" {agent}: {total_rewards[agent]:.2f}")

    # Print statistics
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    print(f"\nStatistics across {num_episodes} episodes:")
    print(f"Mean return: {mean_return:.2f} ± {std_return:.2f}")

    anim = env.animate(state_seq_all, interval=150)
    return anim

anim = main(num_episodes=5, max_steps=30)
HTML(anim.to_jshtml())
# Out:
# Initializing environment...
# Initializing agents...
# Agent 0: SequentialFruitAgent
# Agent 1: SequentialFruitAgent
#
# Episode 1/5
# Episode finished. Total states collected: 13
# Total states in sequence after episode: 13
#
# Episode 1 finished:
# Total steps: 13
# Mean episode return: 0.50
# Episode returns per agent:
#  agent_0: 0.50
#  agent_1: 0.50
#
# Episode 2/5
# Episode finished. Total states collected: 16
# Total states in sequence after episode: 29
#
# Episode 2 finished:
# Total steps: 16
# Mean episode return: 0.50
# Episode returns per agent:
#  agent_0: 0.50
#  agent_1: 0.50
#
# Episode 3/5
# Episode finished. Total states collected: 30
# Total states in sequence after episode: 59
#
# Episode 3 finished:
# Total steps: 30
# Mean episode return: 0.00
# Episode returns per agent:
#  agent_0: 0.00
#  agent_1: 0.00
#
# Episode 4/5
# Episode finished. Total states collected: 14
# Total states in sequence after episode: 73
#
# Episode 4 finished:
# Total steps: 14
# Mean episode return: 0.50
# Episode returns per agent:
#  agent_0: 0.50
#  agent_1: 0.50
#
# Episode 5/5
# Episode finished. Total states collected: 30
# Total states in sequence after episode: 103
#
# Episode 5 finished:
# Total steps: 30
# Mean episode return: 0.00
# Episode returns per agent:
#  agent_0: 0.00
#  agent_1: 0.00
#
# Statistics across 5 episodes:
# Mean return: 0.30 ± 0.24
# <div id='27a47b8b-f2da-46b1-a379-102ffe45f101'></div>
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5f779357c726455cb4d310b0ce995706">
#   <div class="anim-controls">
#     <input id="_anim_slider5f779357c726455cb4d310b0ce995706" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5f779357c726455cb4d310b0ce995706.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5f779357c726455cb4d310b0ce995706.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5f779357c726455cb4d310b0ce995706.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5f779357c726455cb4d310b0ce995706.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5f779357c726455cb4d310b0ce995706.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5f779357c726455cb4d310b0ce995706.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5f779357c726455cb4d310b0ce995706.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5f779357c726455cb4d310b0ce995706.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5f779357c726455cb4d310b0ce995706.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5f779357c726455cb4d310b0ce995706.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5f779357c726455cb4d310b0ce995706"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5f779357c726455cb4d310b0ce995706"
#              >
#       <label for="_anim_radio1_5f779357c726455cb4d310b0ce995706">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5f779357c726455cb4d310b0ce995706"
#              checked>
#       <label for="_anim_radio2_5f779357c726455cb4d310b0ce995706">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5f779357c726455cb4d310b0ce995706"
#              >
#       <label for="_anim_radio3_5f779357c726455cb4d310b0ce995706">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5f779357c726455cb4d310b0ce995706";
#     var slider_id = "_anim_slider5f779357c726455cb4d310b0ce995706";
#     var loop_select_id = "_anim_loop_select5f779357c726455cb4d310b0ce995706";
#     var frames = new Array(103);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuNSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/xnp5ZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAA9/0lE
