# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinewang01/jax-aht/blob/main/JaxAHT_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to JaxAHT!
#
# In this tutorial, we will focus on introducing the core workflows for using the library.
# We will:
# - Demonstrate how to train teammates and ego agents, separately and as part of a single, unified workflow.
# - Introduce the set of evaluation teammates and the evaluation framework
# - Visualize learned policies
#
# The project uses [Hydra](https://hydra.cc/) to manage algorithm and environment configurations, and [WandB](https://wandb.ai/) for logging.
#
# Although the tutorial does not explicitly describe how to run the open-ended learning algorithms, these algorithm types may be run similarly to the MARL, teammate generation, and ego agent training algorithms.
#
# Please see the project README for a full description of the project's design philosophy.
# Our benchmark uses a multi-agent PPO implementation provided by [JaxMARL](https://github.com/FLAIROx/JaxMARL/tree/main).

# %% [markdown]
# # Install dependencies 📚
#
#  ⚠️ Before beginning the tutorial, ensure you select a GPU or TPU from `Runtime > Change runtime type` ⚠️

# %%
# %%shell
# # clone repo and install packages
# git clone https://github.com/carolinewang01/jax-aht.git
# cd jax-aht
# pip install --upgrade pip
# pip install -r requirements.txt
# Out:
# Cloning into 'jax-aht'...
# remote: Enumerating objects: 5722, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 5722 (delta 113), reused 145 (delta 93), pack-reused 5531 (from 1)
# Receiving objects: 100% (5722/5722), 2.58 MiB | 6.05 MiB/s, done.
# Resolving deltas: 100% (4037/4037), done.
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Requirement already satisfied: jax==0.5.3 in /usr/local/lib/python3.11/dist-packages (from jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: chex==0.1.88 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.1.88)
# Requirement already satisfied: flax==0.10.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: ml_dtypes==0.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: optax==0.2.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: orbax-checkpoint==0.11.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.11.1)
# Requirement already satisfied: orbax-export==0.0.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.0.6)
# Requirement already satisfied: gymnax in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.0.9)
# Requirement already satisfied: distrax in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.1.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (1.0.3)
# Requirement already satisfied: ffmpeg in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (1.4)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (3.16.0)
# Requirement already satisfied: rliable in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (3.7.5)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (0.20.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (2.3.0)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (1.3.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (5.24.1)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (5.2.0)
# Requirement already satisfied: jumanji==1.1.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (1.1.0)
# Requirement already satisfied: jaxmarl==0.0.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (0.0.7)
# Requirement already satisfied: jaxlib<=0.5.3,>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from jax==0.5.3->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax==0.5.3->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax==0.5.3->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax==0.5.3->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: absl-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex==0.1.88->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: typing_extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from chex==0.1.88->-r requirements.txt (line 3)) (4.14.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex==0.1.88->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax==0.10.2->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax==0.10.2->-r requirements.txt (line 4)) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax==0.10.2->-r requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax==0.10.2->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax==0.2.4->-r requirements.txt (line 6)) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (3.20.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from orbax-export==0.0.6->-r requirements.txt (line 8)) (0.6.7)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.11/dist-packages (from orbax-export==0.0.6->-r requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: dm-env>=1.5 in /usr/local/lib/python3.11/dist-packages (from jumanji==1.1.0->-r requirements.txt (line 26)) (1.6)
# Requirement already satisfied: gymnasium>=1.0 in /usr/local/lib/python3.11/dist-packages (from jumanji==1.1.0->-r requirements.txt (line 26)) (1.2.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from jumanji==1.1.0->-r requirements.txt (line 26)) (0.33.1)
# Requirement already satisfied: Pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from jumanji==1.1.0->-r requirements.txt (line 26)) (11.2.1)
# Requirement already satisfied: brax==0.10.3 in /usr/local/lib/python3.11/dist-packages (from jaxmarl==0.0.7->-r requirements.txt (line 27)) (0.10.3)
# Requirement already satisfied: mujoco==3.1.3 in /usr/local/lib/python3.11/dist-packages (from jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.3)
# Collecting scipy>=1.11.1 (from jax==0.5.3->jax[cuda12]==0.5.3->-r requirements.txt (line 2))
#   Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (6.0.1)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (1.73.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (0.25.2)
# Requirement already satisfied: jaxopt in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (0.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.6)
# Requirement already satisfied: ml-collections in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (1.1.0)
# Requirement already satisfied: mujoco-mjx in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.3)
# Requirement already satisfied: pytinyrenderer in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (0.0.14)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (2.6.4)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.11/dist-packages (from brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (4.6.13)
# Requirement already satisfied: jax-cuda12-plugin<=0.5.3,>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: glfw in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (2.9.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 18)) (2.9.0.post0)
# Requirement already satisfied: jax-cuda12-pjrt==0.5.3 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin<=0.5.3,>=0.5.3->jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.5.3.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.5.82)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.6.85 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.5.82)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (9.3.0.75)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (11.2.3.61)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (11.6.3.83)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.5.1.3)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.3,>=0.5.3; extra == "cuda12"->jax[cuda12]==0.5.3->-r requirements.txt (line 2)) (12.5.82)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from gymnax->-r requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: tensorflow-probability>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from distrax->-r requirements.txt (line 12)) (0.25.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->-r requirements.txt (line 14)) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (2025.6.15)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->-r requirements.txt (line 16)) (0.2.13)
# Requirement already satisfied: arch<8.0,>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from rliable->-r requirements.txt (line 17)) (7.2.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.11/dist-packages (from rliable->-r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=5.3.1->rliable->-r requirements.txt (line 17)) (0.14.4)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (4.3.8)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (2.32.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 19)) (1.3.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 19)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 19)) (0.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->-r requirements.txt (line 20)) (4.9.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->-r requirements.txt (line 22)) (8.5.0)
# Requirement already satisfied: choreographer>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from kaleido->-r requirements.txt (line 23)) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from kaleido->-r requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.11/dist-packages (from kaleido->-r requirements.txt (line 23)) (3.10.18)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->-r requirements.txt (line 24)) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->-r requirements.txt (line 24)) (3.18.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from dm-env>=1.5->jumanji==1.1.0->-r requirements.txt (line 26)) (0.1.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 19)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 19)) (5.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0->jumanji==1.1.0->-r requirements.txt (line 26)) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0->jumanji==1.1.0->-r requirements.txt (line 26)) (0.0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0->rliable->-r requirements.txt (line 17)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0->rliable->-r requirements.txt (line 17)) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 18)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax==0.10.2->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax==0.10.2->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax==0.10.2->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch<8.0,>=5.3.1->rliable->-r requirements.txt (line 17)) (1.0.1)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.15.0->distrax->-r requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->-r requirements.txt (line 24)) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->orbax-export==0.0.6->-r requirements.txt (line 8)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->orbax-export==0.0.6->-r requirements.txt (line 8)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->orbax-export==0.0.6->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->dm-env>=1.5->jumanji==1.1.0->-r requirements.txt (line 26)) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree->dm-env>=1.5->jumanji==1.1.0->-r requirements.txt (line 26)) (1.17.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint==0.11.1->-r requirements.txt (line 7)) (3.23.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask->brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask->brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask->brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flask->brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (3.1.3)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym->brax==0.10.3->jaxmarl==0.0.7->-r requirements.txt (line 27)) (0.0.8)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->jumanji==1.1.0->-r requirements.txt (line 26)) (1.1.5)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from jaxtyping->orbax-export==0.0.6->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->-r requirements.txt (line 24)) (1.7.1)
# Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotnine 0.14.6 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# Successfully installed scipy-1.12.0

# %%
# change current working directory to rotate/ for the rest of this notebook
import os
os.chdir('jax-aht/')
os.getcwd()

# verify that the jax installation can find the GPU/TPU
import jax
jax.devices()
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# ## Part 1.1 Training Teammates
#
#
# In Jax-AHT, teammates may be trained using either MARL algorithms, or teammate generation algorithms. Each algorithm type has its own entry point, located at `marl/run.py` and `teammate_generation/run.py` respectively.
# For this tutorial, we will train teammates on Level-Based Foraging (LBF) using IPPO.
#
#
# **Viewing Metrics:**    We strongly recommend using WandB's UI to view the logged metrics. You will need a WandB account, and to set the logger to online mode. For the purposes of this tutorial, you can see a preview of the loggged metrics in the console. Note that the maximum return on LBF is 0.5.

# %%
# %%shell
# # train teammates on LBF using a MARL algorithm (IPPO w/parameter sharing)
# PYTHONPATH=$(pwd) python marl/run.py task=lbf algorithm=ippo/lbf logger.mode=offline
# # train using BRDiv instead. Note that we use the teammate_generation/ entry point instead of the marl/ entry point.
# # PYTHONPATH=$(pwd) python teammate_generation/run.py task=lbf algorithm=brdiv/lbf logger.mode=offline
# Out:
# 2025-07-08 00:38:39.127718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751935119.147399    2689 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751935119.153491    2689 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# task:
#   ENV_NAME: lbf
#   ROLLOUT_LENGTH: 128
#   ENV_KWARGS: {}
#   TASK_NAME: lbf
# algorithm:
#   ALG: ippo
#   TOTAL_TIMESTEPS: 500000.0
#   ACTOR_TYPE: mlp
#   NUM_CHECKPOINTS: 5
#   GAMMA: 0.99
#   GAE_LAMBDA: 0.95
#   VF_COEF: 0.5
#   MAX_GRAD_NORM: 1.0
#   ANNEAL_LR: true
#   SEED: 12345
#   LR: 0.0001
#   NUM_ENVS: 8
#   UPDATE_EPOCHS: 15
#   NUM_MINIBATCHES: 4
#   CLIP_EPS: 0.03
#   ENT_COEF: 0.01
#   NUM_SEEDS: 3
#   TRAIN_SEED: 20374
#   ENV_NAME: lbf
#   ENV_KWARGS: {}
#   ROLLOUT_LENGTH: 128
# ENV_NAME: lbf
# ENV_KWARGS: {}
# ROLLOUT_LENGTH: 128
# TASK_NAME: lbf
# label: default_label
# name: lbf/ippo/default_label
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#   - ippo
#   - lbf
#   - seed=20374
#   - default_label
#   mode: offline
#   verbose: false
#   log_train_out: true
#   log_eval_out: true
# local_logger:
#   save_train_out: true
#   save_eval_out: true
#
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: Tracking run with wandb version 0.20.1
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# wandb: Adding directory to artifact (/content/jax-aht/results/lbf/ippo/default_label/2025-07-08_00-38-56/saved_train_run)... Done. 0.0s
# wandb:
# wandb:
# wandb: Run history:
# wandb: Train/returned_episode_returns ▁▁▂▂▃▄▄▅▅▅▆▅▆▇▇▇▇▇██▇████████▇██████████
# wandb:                     train_step ▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▅▅▅▅▅▆▆▆▇▇▇▇███
# wandb:
# wandb: Run summary:
# wandb: Train/returned_episode_returns 0.49015
# wandb:                     train_step 487
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/jax-aht/results/lbf/ippo/default_label/2025-07-08_00-38-56/wandb/offline-run-20250708_003856-46qhqwwc
# wandb: Find logs at: ./wandb/offline-run-20250708_003856-46qhqwwc/logs

# %% [markdown]
# ## Part 1.2: Training an Ego Agent Against Pretrained Teammate
#
# Using the IPPO teammates trained in the last section, here, we will train a PPO ego agent to collaborate with those teammates, using the ego agent training entry point at `ego_agent_training/run.py`.
#
# Please take a moment to look over the entry point code, to understand the overall pipeline.

# %%
! cat ego_agent_training/run.py
# Out:
# '''Main entry point for running ego agent training algorithms against a fixed partner population.'''
# import hydra
# from omegaconf import OmegaConf
#
# from common.plot_utils import get_metric_names
# from common.wandb_visualizations import Logger
# from evaluation.heldout_eval import run_heldout_evaluation, log_heldout_metrics
# from ppo_ego import run_ego_training
# from ego_agent_training.ppo_br import run_br_training
#
#
# @hydra.main(version_base=None, config_path="configs", config_name="base_config_ego")
# def run_training(cfg):
#     '''Runs the ego agent training against a fixed partner population.'''
#     print(OmegaConf.to_yaml(cfg, resolve=True))
#     wandb_logger = Logger(cfg)
#
#     if cfg["algorithm"]["ALG"] == "ppo_ego":
#         ego_params, ego_policy, init_ego_params = run_ego_training(cfg, wandb_logger)
#     elif cfg["algorithm"]["ALG"] == "ppo_br":
#         ego_params, ego_policy, init_ego_params = run_br_training(cfg, wandb_logger)
#
#     if cfg["run_heldout_eval"]:
#         metric_names = get_metric_names(cfg["ENV_NAME"])
#         eval_metrics, ego_names, heldout_names = run_heldout_evaluation(cfg, ego_policy, ego_params, init_ego_params, ego_as_2d=False)
#         log_heldout_metrics(cfg, wandb_logger, eval_metrics, ego_names, heldout_names, metric_names, ego_as_2d=False)
#
#     # Cleanup
#     wandb_logger.close()
#
#
# if __name__ == '__main__':
#     run_training()

# %% [markdown]
# ### 1.2.1: Setting the Partner Config
#
# The first step to training an ego agent is to specify what teammates the ego agent should be trained with.
# The ego agent training code looks for a partner config within the algorithm block of the master config file, located at `rotate/ego_agent_training/configs/base_config_ego.yaml`.

# %%
! cat ego_agent_training/configs/base_config_ego.yaml
# Out:
# defaults:
#   - task: overcooked-v1/cramped_room # task configs
#   - algorithm@algorithm: ppo_ego/${task} # task-specific algorithm configs
#   - hydra: hydra_simple
#   - ../../evaluation/configs/global_heldout_settings
#   - _self_         # Ensures that values in this file override imported ones if needed
#
# ENV_NAME: ${task.ENV_NAME}
# ENV_KWARGS: ${task.ENV_KWARGS}
# ROLLOUT_LENGTH: ${task.ROLLOUT_LENGTH}
# TASK_NAME: ${task.TASK_NAME}
#
# run_heldout_eval: true
#
# # partner configs are specified in each algorithm _base_ config file
# # note that ppo_ego and ppo_br support different types of partner configs
# algorithm:
#   TRAIN_SEED: 12345
#   NUM_EGO_TRAIN_SEEDS: 3
#   NUM_EVAL_EPISODES: 20
#   ENV_NAME: ${ENV_NAME}
#   ENV_KWARGS: ${ENV_KWARGS}
#   ROLLOUT_LENGTH: ${ROLLOUT_LENGTH}
#
# label: "default_label"
# name: ${TASK_NAME}/${algorithm.ALG}_${algorithm.EGO_ACTOR_TYPE}/${label}
#
# # WandB Params
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#     - ${algorithm.ALG}
#     - ${TASK_NAME}
#     - ${label}
#   mode: offline # options: online, offline, disabled
#   verbose: false
#   log_train_out: true # whether to log the out dictionary
#   log_eval_out: true # whether to log the eval metrics
#
# # Local logger
# local_logger:
#   save_train_out: true
#   save_eval_out: true

# %% [markdown]
# For the ppo_ego algorithm, a default partner config is specified within the algorithm-specific config directory, at `rotate/ego_agent_training/configs/algorithm/ppo_ego/_base_.yaml`. This default partner config is automatically imported and merged into the master config. The path (and other partner config values) should be set by the user, either directly within the config or via the command line. We will take the latter approach in this tutorial.

# %%
! cat ego_agent_training/configs/algorithm/ppo_ego/_base_.yaml
# Out:
# # @package algorithm
# # ^ tells hydra to place these value directly under algorithm key
# ALG: ppo_ego
# EGO_ACTOR_TYPE: s5
# NUM_EGO_TRAIN_SEEDS: 1
# TOTAL_TIMESTEPS: 1e7
# NUM_CHECKPOINTS: 5
# NUM_ENVS: 8
# LR: 1.e-4
# UPDATE_EPOCHS: 15
# NUM_MINIBATCHES: 4
# GAMMA: 0.99
# GAE_LAMBDA: 0.95
# CLIP_EPS: 0.05
# ENT_COEF: 0.01
# VF_COEF: 0.5
# MAX_GRAD_NORM: 1.0
# ANNEAL_LR: true
# partner_agent: # partner config for ppo_ego
#   name: ippo
#   path: null # Please set the path to a partner agent checkpoint. You will also need to set the actor_type, ckpt_key, and specify the partner idxs to load.
#   actor_type: mlp
#   ckpt_key: final_params
#   idx_list: [0]

# %%
# First, let's find the teammate checkpoint directory
import glob

checkpoint_base_dir = 'results/lbf/ippo/default_label/'
checkpoint_dir = sorted(glob.glob(os.path.join(checkpoint_base_dir, '*')))[-1]
checkpoint_dir = os.path.join(checkpoint_dir, "saved_train_run")
assert os.path.exists(checkpoint_dir), "Error: checkpoint directory not found."
print(f"Found checkpoint directory: {checkpoint_dir}")
# Out:
# Found checkpoint directory: results/lbf/ippo/default_label/2025-07-07_02-34-21/saved_train_run

# %% [markdown]
# ### 1.2.2: Train the ego agent!
#
# Now let's train the ego agent, directly specifying the partner path as a command line argument. We reduce the training time to 1 million steps, so that the ego agent trains in a couple minutes. We also turn off the evaluation against the heldout set, which is explained in the next section.

# %%
# Now let's train the ego agent, directly specifying the partner path from the command line
# total training timesteps is reduced to 1 million steps for this tutorial.
! PYTHONPATH=$(pwd) python ego_agent_training/run.py task=lbf algorithm=ppo_ego/lbf algorithm.partner_agent.path={checkpoint_dir} algorithm.TOTAL_TIMESTEPS=1e6 run_heldout_eval=false logger.mode=offline
# Out:
# 2025-07-07 02:56:01.721169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751856961.743478   10427 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751856961.750090   10427 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# task:
#   ENV_NAME: lbf
#   ROLLOUT_LENGTH: 128
#   ENV_KWARGS: {}
#   TASK_NAME: lbf
# algorithm:
#   ALG: ppo_ego
#   EGO_ACTOR_TYPE: s5
#   NUM_EGO_TRAIN_SEEDS: 3
#   TOTAL_TIMESTEPS: 1000000.0
#   NUM_CHECKPOINTS: 5
#   NUM_ENVS: 8
#   LR: 5.0e-05
#   UPDATE_EPOCHS: 10
#   NUM_MINIBATCHES: 4
#   GAMMA: 0.99
#   GAE_LAMBDA: 0.95
#   CLIP_EPS: 0.1
#   ENT_COEF: 0.0001
#   VF_COEF: 0.5
#   MAX_GRAD_NORM: 1.0
#   ANNEAL_LR: false
#   partner_agent:
#     name: ippo
#     path: results/lbf/ippo/default_label/2025-07-07_02-34-21/saved_train_run
#     actor_type: mlp
#     ckpt_key: final_params
#     idx_list:
#     - 0
#   S5_D_MODEL: 128
#   S5_SSM_SIZE: 128
#   S5_ACTOR_CRITIC_HIDDEN_DIM: 1024
#   FC_N_LAYERS: 3
#   TRAIN_SEED: 12345
#   NUM_EVAL_EPISODES: 20
#   ENV_NAME: lbf
#   ENV_KWARGS: {}
#   ROLLOUT_LENGTH: 128
# global_heldout_settings:
#   EVAL_SEED: 34957
#   MAX_EPISODE_STEPS: 128
#   NUM_EVAL_EPISODES: 64
#   AGGREGATE_STAT: mean
#   NORMALIZE_RETURNS: true
# heldout_set:
#   lbf:
#     ippo_mlp:
#       path: eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 100.0
#         returned_episode_returns:
#         - - 0.0
#           - 0.5
#     ippo_mlp_s2c0:
#       path: eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run
#       actor_type: mlp
#       idx_list:
#       - - 2
#         - 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 69.27
#         returned_episode_returns:
#         - - 0.0
#           - 0.35
#     brdiv-conf1:
#       path: eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 5
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 61.98
#         - - 0.0
#           - 83.33
#         - - 0.0
#           - 78.65
#         returned_episode_returns:
#         - - 0.0
#           - 0.31
#         - - 0.0
#           - 0.42
#         - - 0.0
#           - 0.39
#     brdiv-conf2:
#       path: eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       test_mode: false
#       performance_bounds:
#         percent_eaten:
#         - - 0.0
#           - 90.62
#         - - 0.0
#           - 52.08
#         returned_episode_returns:
#         - - 0.0
#           - 0.45
#         - - 0.0
#           - 0.26
#     seq_agent_lexi:
#       actor_type: seq_agent
#       ordering_strategy: lexicographic
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_rlexi:
#       actor_type: seq_agent
#       ordering_strategy: reverse_lexicographic
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_col:
#       actor_type: seq_agent
#       ordering_strategy: column_major
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_rcol:
#       actor_type: seq_agent
#       ordering_strategy: reverse_column_major
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_nearest:
#       actor_type: seq_agent
#       ordering_strategy: nearest_agent
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#     seq_agent_farthest:
#       actor_type: seq_agent
#       ordering_strategy: farthest_agent
#       performance_bounds:
#         percent_eaten:
#         - 0.0
#         - 100.0
#         returned_episode_returns:
#         - 0.0
#         - 0.5
#   overcooked-v1/cramped_room:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/cramped_room/ippo/2025-04-21_22-53-04/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 196.25
#         - - 0.0
#           - 180.94
#         - - 0.0
#           - 211.88
#         returned_episode_returns:
#         - - 0.0
#           - 209.55
#         - - 0.0
#           - 193.39
#         - - 0.0
#           - 226.68
#     brdiv-conf:
#       path: eval_teammates/overcooked-v1/cramped_room/brdiv/2025-04-23-12-55-47/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 204.06
#         - - 0.0
#           - 240.94
#         returned_episode_returns:
#         - - 0.0
#           - 217.77
#         - - 0.0
#           - 257.61
#     independent_agent_0.4:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.4
#       p_plate_on_counter: 0.4
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 158.75
#         returned_episode_returns:
#         - 0.0
#         - 169.27
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 132.5
#         returned_episode_returns:
#         - 0.0
#         - 133.64
#     onion_agent_0.1:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.1
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 83.13
#         returned_episode_returns:
#         - 0.0
#         - 89.34
#     plate_agent_0.1:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.1
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 137.5
#         returned_episode_returns:
#         - 0.0
#         - 146.45
#   overcooked-v1/asymm_advantages:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/asymm_advantages/ippo/2025-04-21_22-53-56/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 91.56
#         - - 0.0
#           - 117.5
#         - - 0.0
#           - 153.44
#         returned_episode_returns:
#         - - 0.0
#           - 91.56
#         - - 0.0
#           - 117.5
#         - - 0.0
#           - 153.44
#     brdiv-conf:
#       path: eval_teammates/overcooked-v1/asymm_advantages/brdiv/2025-04-23/13-16-34/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 157.81
#         - - 0.0
#           - 148.44
#         - - 0.0
#           - 160.0
#         returned_episode_returns:
#         - - 0.0
#           - 157.81
#         - - 0.0
#           - 148.44
#         - - 0.0
#           - 160.0
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 257.5
#         returned_episode_returns:
#         - 0.0
#         - 257.5
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 199.69
#         returned_episode_returns:
#         - 0.0
#         - 199.69
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 191.25
#         returned_episode_returns:
#         - 0.0
#         - 191.25
#   overcooked-v1/counter_circuit:
#     ippo_mlp_cc:
#       path: eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-21_22-55-42/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 196.88
#         - - 0.0
#           - 198.12
#         - - 0.0
#           - 189.06
#         returned_episode_returns:
#         - - 0.0
#           - 209.12
#         - - 0.0
#           - 210.51
#         - - 0.0
#           - 207.01
#     ippo_mlp_pass:
#       path: eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-23_15-28-23/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 59.38
#         - - 0.0
#           - 46.25
#         - - 0.0
#           - 142.5
#         returned_episode_returns:
#         - - 0.0
#           - 62.86
#         - - 0.0
#           - 47.63
#         - - 0.0
#           - 150.6
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 65.0
#         returned_episode_returns:
#         - 0.0
#         - 65.5
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 62.5
#         returned_episode_returns:
#         - 0.0
#         - 65.93
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 56.25
#         returned_episode_returns:
#         - 0.0
#         - 58.79
#     onion_agent_0.9:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.9
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 46.25
#         returned_episode_returns:
#         - 0.0
#         - 48.62
#     plate_agent_0.9:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.9
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 55.31
#         returned_episode_returns:
#         - 0.0
#         - 57.91
#   overcooked-v1/coord_ring:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/coord_ring/ippo/2025-04-21_22-58-26/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 1
#       - 2
#       - 3
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 218.44
#         - - 0.0
#           - 246.56
#         - - 0.0
#           - 246.56
#         returned_episode_returns:
#         - - 0.0
#           - 232.62
#         - - 0.0
#           - 262.83
#         - - 0.0
#           - 262.83
#     brdiv-conf1:
#       path: eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_15-00-27/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 1
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 161.25
#         - - 0.0
#           - 183.44
#         returned_episode_returns:
#         - - 0.0
#           - 171.35
#         - - 0.0
#           - 194.6
#     brdiv-conf2:
#       path: eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 142.81
#         returned_episode_returns:
#         - - 0.0
#           - 150.98
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 136.25
#         returned_episode_returns:
#         - 0.0
#         - 137.08
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 38.13
#         returned_episode_returns:
#         - 0.0
#         - 40.25
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 67.5
#         returned_episode_returns:
#         - 0.0
#         - 70.33
#   overcooked-v1/forced_coord:
#     ippo_mlp:
#       path: eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/saved_train_run
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list:
#       - 0
#       - 1
#       - 2
#       test_mode: true
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 220.0
#         - - 0.0
#           - 214.38
#         - - 0.0
#           - 225.62
#         returned_episode_returns:
#         - - 0.0
#           - 233.83
#         - - 0.0
#           - 227.73
#         - - 0.0
#           - 239.82
#     brdiv-conf1:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_19-44-30/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 131.56
#         - - 0.0
#           - 184.69
#         returned_episode_returns:
#         - - 0.0
#           - 139.33
#         - - 0.0
#           - 195.88
#     brdiv-conf2:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_20-25-28/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 1
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 143.75
#         returned_episode_returns:
#         - - 0.0
#           - 152.5
#     brdiv-conf3:
#       path: eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_21-06-05/saved_train_run
#       actor_type: actor_with_conditional_critic
#       idx_list:
#       - 0
#       - 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return:
#         - - 0.0
#           - 69.06
#         - - 0.0
#           - 174.69
#         returned_episode_returns:
#         - - 0.0
#           - 72.45
#         - - 0.0
#           - 185.49
#     independent_agent_0.6:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.6
#       p_plate_on_counter: 0.6
#       performance_bounds:
#         base_return:
#         - 0.0
#         - 61.88
#         returned_episode_returns:
#         - 0.0
#         - 65.22
# ENV_NAME: lbf
# ENV_KWARGS: {}
# ROLLOUT_LENGTH: 128
# TASK_NAME: lbf
# run_heldout_eval: false
# label: default_label
# name: lbf/ppo_ego_s5/default_label
# logger:
#   project: aht-benchmark
#   entity: aht-project
#   tags:
#   - ppo_ego
#   - lbf
#   - default_label
#   mode: offline
#   verbose: false
#   log_train_out: true
#   log_eval_out: true
# local_logger:
#   save_train_out: true
#   save_eval_out: true
#
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: Tracking run with wandb version 0.20.1
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/serialization/type_handlers.py:1167: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(
# [2025-07-07 02:56:06,982][common.agent_loader_from_config][INFO] - Loaded ippo checkpoint where leaf 0 has shape (3, 64).  Selecting indices [0] for evaluation.
# [2025-07-07 02:56:24,329][ppo_ego][INFO] - Starting ego agent training...
# /usr/local/lib/python3.11/dist-packages/jax/_src/lax/lax.py:5125: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_bar = _convert_element_type(x_bar, x.aval.dtype, x.aval.weak_type)
# [2025-07-07 03:06:00,474][ppo_ego][INFO] - Training completed in 576.15 seconds
# wandb: Adding directory to artifact (/content/jax-aht/results/lbf/ppo_ego_s5/default_label/2025-07-07_02-56-04/ego_train_run)... Done. 1.6s
# wandb:
# wandb:
# wandb: Run history:
# wandb:                     Eval/EgoReturn ▁▁▁▁▁▁▁▁▁▁▁█████████████████████████████
# wandb:                 Train/EgoActorLoss ▂▁▂▃▄▅▅▇▆▄▃▃▅█▄█▅▃▆▇▃▅▄▄▄▃▄▄▄▃▆▃▃▂▃▅▂▃▂▂
# wandb:               Train/EgoEntropyLoss █▄▄▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  Train/EgoGradNorm ▁▂▅▇▅█▄▅▅▄▄▄▄▄▅▄▄▃▄▂▄▄▃▄▃▃▃▃▅▃▂▃▁▂▂▂▃▂▄▂
# wandb:                 Train/EgoValueLoss █▂▃▂▂▂▂▂▁▂▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Ego_returned_episode_returns ▁▅▅▆▇▇▆▇▇█▇▇▇▇▇█▇███▇██▇███▇████████████
# wandb:                         train_step ▁▁▁▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██
# wandb:
# wandb: Run summary:
# wandb:                     Eval/EgoReturn 0.48611
# wandb:                 Train/EgoActorLoss -0.01272
# wandb:               Train/EgoEntropyLoss 0.31233
# wandb:                  Train/EgoGradNorm 0.12784
# wandb:                 Train/EgoValueLoss 0.0006
# wandb: Train/Ego_returned_episode_returns 0.49786
# wandb:                         train_step 975
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/jax-aht/results/lbf/ppo_ego_s5/default_label/2025-07-07_02-56-04/wandb/offline-run-20250707_025604-714nrc96
# wandb: Find logs at: ./wandb/offline-run-20250707_025604-714nrc96/logs

# %% [markdown]
# # 2. Evaluation
#
# In AHT research, ego agents are often evaluated based on the returns achieved during collaboration with a *heldout set* of evaluation agents---i.e., agents that should not have been seen during training.
# The JaxAHT benchmark provides a heldout evaluation set for LBF, and the 5 classic Overcooked tasks.
# The rliable library is used to compute bootstrapped metrics across the heldout set, by treating each heldout agent as a task.
# In this section of the tutorial, we will introduce the heldout agent config, demonstrate how to download the agents, and visualize them.
#
# *Note that the ego agent training entry point evaluate the ego agent against the heldout set by default. We turned this off in the last section, but you simply need to set the `run_heldout_eval` argument to true in order to enable evaluation.

# %% [markdown]
#  ## 2.1 Download the Heldout Set
#
#
#  The heldout evaluation set consists of both agents trained via RL, and manually programmed heuristic agents. The heuristic agents are located under the `agents/lbf/` and `agents/overcooked/` directories, while the following code will download the RL agent checkpoints to an `eval_teammates/` directory.

# %%
# first, let's download the RL agents in the heldout set
! python download_eval_data.py
# Out:
# Starting download & extraction: https://drive.google.com/file/d/1pS0wvJDzOZa954RADF_j9ETR74THzh8I/view?usp=sharing -> results/
# Downloading...
# From: https://drive.google.com/uc?id=1pS0wvJDzOZa954RADF_j9ETR74THzh8I
# To: /content/jax-aht/results/downloaded_gdrive_file.zip
# 100% 5.94k/5.94k [00:00<00:00, 27.4MB/s]
# Downloaded results/downloaded_gdrive_file.zip (5942 bytes).
# Unzipping results/downloaded_gdrive_file.zip to temporary directory /tmp/tmpbf001ng1...
# Successfully unzipped results/downloaded_gdrive_file.zip to /tmp/tmpbf001ng1.
# Processing and moving files from '/tmp/tmpbf001ng1/best_heldout_returns' to 'results/'...
# Successfully moved 6 file(s) to results/.
# Cleaning up temporary extraction directory: /tmp/tmpbf001ng1
# Download completed successfully for best_returns_teammates.
# Starting download & extraction: https://drive.google.com/file/d/1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7/view?usp=sharing -> eval_teammates/
# Downloading...
# From (original): https://drive.google.com/uc?id=1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7
# From (redirected): https://drive.google.com/uc?id=1KjBV2GekKdRBiK6QSGe2vYx2ThXlG7X7&confirm=t&uuid=593456f0-c69a-43d6-a9eb-b78ecaaf1eb2
# To: /content/jax-aht/eval_teammates/downloaded_gdrive_file.zip
# 100% 852M/852M [00:09<00:00, 91.8MB/s]
# Downloaded eval_teammates/downloaded_gdrive_file.zip (851869349 bytes).
# Unzipping eval_teammates/downloaded_gdrive_file.zip to temporary directory /tmp/tmp8pmunoku...
# Successfully unzipped eval_teammates/downloaded_gdrive_file.zip to /tmp/tmp8pmunoku.
# Processing and moving files from '/tmp/tmp8pmunoku/eval_teammates' to 'eval_teammates/'...
# Successfully moved 1029 file(s) to eval_teammates/.
# Cleaning up temporary extraction directory: /tmp/tmp8pmunoku
# Download completed successfully for eval_teammates.

# %% [markdown]
# ## 2.2. Heldout Agent Config
#
# The evaluation teammate set is specified in the `global_heldout_settings.yaml` file, which is imported by other config files throughout the codebase as needed, to perform the heldout evaluation.
#
# Notice that the teammate config format looks similar to the format used to specify the ego agent training teammates! This is because all teammate configs are parsed by functions within the `common/agent_loader_from_config.py` file. Please see the README for more details about the teammate config.

# %%
! cat evaluation/configs/global_heldout_settings.yaml
# Out:
# # @package _global_
# # THIS SCRIPT CONTAINS THE PATHS FOR THE HELDOUT EVALUATION. DO NOT MODIFY THIS FILE.
# global_heldout_settings:
#   EVAL_SEED: 34957
#   MAX_EPISODE_STEPS: ${task.ROLLOUT_LENGTH}
#   NUM_EVAL_EPISODES: 64
#   AGGREGATE_STAT: mean # choices: mean, iqm. both are computed with the bootstrapped CI using rliable.
#   NORMALIZE_RETURNS: true # if true, use performance bounds to normalize returns
#
# heldout_set:
#   lbf: # DONE - DO NOT MODIFY. In LBF, results are much better with test mode = false.
#     ippo_mlp:
#       path: "eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0] # load in seed 0 only
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 100.0]]
#         returned_episode_returns: [[0.0, 0.5]]
#     ippo_mlp_s2c0:
#       path: "eval_teammates/lbf/ippo/2025-04-21_23-41-17/saved_train_run"
#       actor_type: mlp
#       idx_list: [[2, 0]] # load in seed 2 ckpt 0
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 69.27]]
#         returned_episode_returns: [[0.0, 0.35]]
#     brdiv-conf1:
#       path: "eval_teammates/lbf/brdiv/2025-04-16/11-32-07/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1, 2] # load in population members 0, 1, 2
#       ckpt_key: final_params_conf # key to load from checkpoint.
#       POP_SIZE: 5 # for brdiv, we need to specify population size that the method was trained with
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 61.98], [0.0, 83.33], [0.0, 78.65]]
#         returned_episode_returns: [[0.0, 0.31], [0.0, 0.42], [0.0, 0.39]]
#     brdiv-conf2:
#       path: "eval_teammates/lbf/brdiv/2025-04-23/13-48-47/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       test_mode: false
#       performance_bounds:
#         percent_eaten: [[0.0, 90.62], [0.0, 52.08]]
#         returned_episode_returns: [[0.0, 0.45], [0.0, 0.26]]
#     seq_agent_lexi:
#       actor_type: seq_agent
#       ordering_strategy: lexicographic
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_rlexi:
#       actor_type: seq_agent
#       ordering_strategy: reverse_lexicographic
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_col:
#       actor_type: seq_agent
#       ordering_strategy: column_major
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_rcol:
#       actor_type: seq_agent
#       ordering_strategy: reverse_column_major
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_nearest:
#       actor_type: seq_agent
#       ordering_strategy: nearest_agent
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#     seq_agent_farthest:
#       actor_type: seq_agent
#       ordering_strategy: farthest_agent
#       performance_bounds:
#         percent_eaten: [0.0, 100.0]
#         returned_episode_returns: [0.0, 0.5]
#   overcooked-v1/cramped_room: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/cramped_room/ippo/2025-04-21_22-53-04/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 196.25], [0.0, 180.94], [0.0, 211.88]]
#         returned_episode_returns: [[0.0, 209.55], [0.0, 193.39], [0.0, 226.68]]
#     brdiv-conf:
#       path: "eval_teammates/overcooked-v1/cramped_room/brdiv/2025-04-23-12-55-47/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1] # load in population members 1, 2
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return: [[0.0, 204.06], [0.0, 240.94]]
#         returned_episode_returns: [[0.0, 217.77], [0.0, 257.61]]
#     independent_agent_0.4:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.4
#       p_plate_on_counter: 0.4
#       performance_bounds:
#         base_return: [0.0, 158.75]
#         returned_episode_returns: [0.0, 169.27]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 132.5]
#         returned_episode_returns: [0.0, 133.64]
#     onion_agent_0.1:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.1
#       performance_bounds:
#         base_return: [0.0, 83.13]
#         returned_episode_returns: [0.0, 89.34]
#     plate_agent_0.1:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.1
#       performance_bounds:
#         base_return: [0.0, 137.5]
#         returned_episode_returns: [0.0, 146.45]
#   overcooked-v1/asymm_advantages: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/asymm_advantages/ippo/2025-04-21_22-53-56/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 91.56], [0.0, 117.50], [0.0, 153.44]]
#         returned_episode_returns: [[0.0, 91.56], [0.0, 117.50], [0.0, 153.44]]
#     brdiv-conf:
#       path: "eval_teammates/overcooked-v1/asymm_advantages/brdiv/2025-04-23/13-16-34/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 1, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 4
#       performance_bounds:
#         base_return: [[0.0, 157.81], [0.0, 148.44], [0.0, 160.00]]
#         returned_episode_returns: [[0.0, 157.81], [0.0, 148.44], [0.0, 160.00]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 257.5]
#         returned_episode_returns: [0.0, 257.5]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 199.69]
#         returned_episode_returns: [0.0, 199.69]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 191.25]
#         returned_episode_returns: [0.0, 191.25]
#   overcooked-v1/counter_circuit: # DONE - DO NOT MODIFY
#     ippo_mlp_cc: # counterclockwise mmt
#       path: "eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-21_22-55-42/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 196.88], [0.0, 198.12], [0.0, 189.06]]
#         returned_episode_returns: [[0.0, 209.12], [0.0, 210.51], [0.0, 207.01]]
#     ippo_mlp_pass: # passes onions across counter
#       path: "eval_teammates/overcooked-v1/counter_circuit/ippo/2025-04-23_15-28-23/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 59.38], [0.0, 46.25], [0.0, 142.5]] # RE-EVALUATE
#         returned_episode_returns: [[0.0, 62.86], [0.0, 47.63], [0.0, 150.60]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 65.0]
#         returned_episode_returns: [0.0, 65.5]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 62.5]
#         returned_episode_returns: [0.0, 65.93]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 56.25]
#         returned_episode_returns: [0.0, 58.79]
#     onion_agent_0.9:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.9
#       performance_bounds:
#         base_return: [0.0, 46.25]
#         returned_episode_returns: [0.0, 48.62]
#     plate_agent_0.9:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.9
#       performance_bounds:
#         base_return: [0.0, 55.31]
#         returned_episode_returns: [0.0, 57.91]
#   overcooked-v1/coord_ring: # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/coord_ring/ippo/2025-04-21_22-58-26/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [1, 2, 3]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 218.44], [0.0, 246.56], [0.0, 246.56]]
#         returned_episode_returns: [[0.0, 232.62], [0.0, 262.83], [0.0, 262.83]]
#     brdiv-conf1:
#       path: "eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_15-00-27/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [1, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 161.25], [0.0, 183.44]]
#         returned_episode_returns: [[0.0, 171.35], [0.0, 194.60]]
#     brdiv-conf2:
#       path: "eval_teammates/overcooked-v1/coord_ring/brdiv/2025_04-23_14-17-36/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 142.81]]
#         returned_episode_returns: [[0.0, 150.98]]
#     independent_agent_0:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.0
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 136.25]
#         returned_episode_returns: [0.0, 137.08]
#     onion_agent_0:
#       actor_type: onion_agent
#       p_onion_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 38.13]
#         returned_episode_returns: [0.0, 40.25]
#     plate_agent_0:
#       actor_type: plate_agent
#       p_plate_on_counter: 0.0
#       performance_bounds:
#         base_return: [0.0, 67.5]
#         returned_episode_returns: [0.0, 70.33]
#   overcooked-v1/forced_coord:  # DONE - DO NOT MODIFY
#     ippo_mlp:
#       path: "eval_teammates/overcooked-v1/forced_coord/ippo/2025-04-21_23-00-17/saved_train_run"
#       actor_type: mlp
#       ckpt_key: final_params
#       idx_list: [0, 1, 2]
#       test_mode: true
#       performance_bounds:
#         base_return: [[0.0, 220.00], [0.0, 214.38], [0.0, 225.62]]
#         returned_episode_returns: [[0.0, 233.83], [0.0, 227.73], [0.0, 239.82]]
#     brdiv-conf1:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_19-44-30/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 131.56], [0.0, 184.69]]
#         returned_episode_returns: [[0.0, 139.33], [0.0, 195.88]]
#     brdiv-conf2:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_20-25-28/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [1]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 143.75]]
#         returned_episode_returns: [[0.0, 152.50]]
#     brdiv-conf3:
#       path: "eval_teammates/overcooked-v1/forced_coord/brdiv/2025-04-23_21-06-05/saved_train_run"
#       actor_type: actor_with_conditional_critic
#       idx_list: [0, 2]
#       ckpt_key: final_params_conf
#       POP_SIZE: 3
#       performance_bounds:
#         base_return: [[0.0, 69.06], [0.0, 174.69]]
#         returned_episode_returns: [[0.0, 72.45], [0.0, 185.49]]
#     independent_agent_0.6:
#       actor_type: independent_agent
#       p_onion_on_counter: 0.6
#       p_plate_on_counter: 0.6
#       performance_bounds:
#         base_return: [0.0, 61.88]
#         returned_episode_returns: [0.0, 65.22]

# %% [markdown]
# ## 2.3. Visualizing Agents
#
# We provide functions to visualize agents at `evaluation/vis_episodes.py`.
# Scripts to test the heuristic agents on LBF and Overcooked are also provided at `tests/test_lbf_agents.py` and `tests/test_overcooked_agents.py`.

# %%
import os
import numpy as np
from typing import Dict, Tuple

from IPython.display import HTML
import time
import jax

from envs import make_env
from agents.lbf import RandomAgent, SequentialFruitAgent

def run_episode(env, agent0, agent1, key) -> Tuple[Dict[str, float], int]:
    """Run a single episode with two heuristic agents.
    """
    # Reset environment
    key, subkey = jax.random.split(key)
    obs, state = env.reset(subkey)

    # Initialize episode tracking
    done = {agent: False for agent in env.agents}
    done['__all__'] = False
    total_rewards = {agent: 0.0 for agent in env.agents}
    num_steps = 0

    # Initialize agent states
    agent0_state = agent0.init_agent_state(0)
    agent1_state = agent1.init_agent_state(1)

    # Initialize state sequence
    state_seq = []
    while not done['__all__']:
        # Get actions from both agents with their states
        key, act0_rng, act1_rng = jax.random.split(key, 3)

        action0, agent0_state = agent0.get_action(obs["agent_0"], state, agent0_state, act0_rng)
        action1, agent1_state = agent1.get_action(obs["agent_1"], state, agent1_state, act1_rng)

        actions = {"agent_0": action0, "agent_1": action1}

        # Step environment
        key, subkey = jax.random.split(key)
        obs, state, rewards, done, info = env.step(subkey, state, actions)
        state_seq.append(state)

        # Update rewards
        for agent in env.agents:
            total_rewards[agent] += rewards[agent]

        num_steps += 1

    print(f"Episode finished. Total states collected: {len(state_seq)}")
    return total_rewards, num_steps, state_seq

def main(num_episodes,
         max_steps=100,
         visualize=False,
         save_video=False):
    print("Initializing environment...")
    env = make_env(env_name="lbf", env_kwargs={"time_limit": max_steps})

    print("Initializing agents...")
    # choices: lexicographic, reverse_lexicographic, column_major, reverse_column_major, nearest_agent, farthest_agent
    agent0 = SequentialFruitAgent(grid_size=7, num_fruits=3, ordering_strategy='lexicographic') # boxed
    agent1 = SequentialFruitAgent(grid_size=7, num_fruits=3, ordering_strategy='lexicographic') # not boxed

    print("Agent 0:", agent0.get_name())
    print("Agent 1:", agent1.get_name())

    # Run multiple episodes
    key = jax.random.PRNGKey(0)

    returns = []
    state_seq_all = []
    for episode in range(num_episodes):
        print(f"\nEpisode {episode + 1}/{num_episodes}")
        key, subkey = jax.random.split(key)
        total_rewards, num_steps, ep_states = run_episode(env, agent0, agent1, subkey)
        state_seq_all.extend(ep_states)  # Changed from += to extend for better list handling
        print(f"Total states in sequence after episode: {len(state_seq_all)}")

        # Calculate episode return
        episode_return = np.mean(list(total_rewards.values()))
        returns.append(episode_return)

        print(f"\nEpisode {episode + 1} finished:")
        print(f"Total steps: {num_steps}")
        print(f"Mean episode return: {episode_return:.2f}")
        print("Episode returns per agent:")
        for agent in env.agents:
            print(f" {agent}: {total_rewards[agent]:.2f}")

    # Print statistics
    mean_return = np.mean(returns)
    std_return = np.std(returns)
    print(f"\nStatistics across {num_episodes} episodes:")
    print(f"Mean return: {mean_return:.2f} ± {std_return:.2f}")

    anim = env.animate(state_seq_all, interval=150)
    return anim

anim = main(num_episodes=5, max_steps=30)
HTML(anim.to_html5_video())
# Out:
# Initializing environment...
# Environment initialized
# Initializing agents...
# Agents initialized
# Agent 0: SequentialFruitAgent
# Agent 1: SequentialFruitAgent
#
# Episode 1/1
# Episode finished. Total states collected: 13
# Total states in sequence after episode: 13
#
# Episode 1 finished:
# Total steps: 13
# Mean episode return: 0.50
# Episode returns per agent:
#  agent_0: 0.50
#  agent_1: 0.50
#
# Statistics across 1 episodes:
# Mean return: 0.50 ± 0.00
# <video width="500" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
